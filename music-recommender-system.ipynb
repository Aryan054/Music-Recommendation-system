# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ADMIN\Downloads\spotify_millsongdata.csv.zip")

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df =df.sample(5000).drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#             artist                            song  \
# 0   Lynyrd Skynyrd          Outta Hell In My Dodge
# 1     Howard Jones                   Roll Right Up
# 2  Harry Belafonte  Zombie Jamboree (Back To Back)
# 3  Doobie Brothers            Feelin' Down Farther
# 4             Rush                        Red Tide
# 5         Bee Gees                 Cucumber Castle
# 6    Peter Gabriel             This Is The Picture
# 7          Outkast                          Bowtie
# 8        Ofra Haza                   Da'ale Da'ale
# 9       Tim McGraw        Some Things Never Change
#
#                                                 text
# 0  Five AM in the mornin', whiskey still runnin' ...
# 1  Will the moon keep shining on  \r\nCan you sto...
# 2  Lyrics:  \r\nIt was a Zombie Jamboree  \r\nToo...
# 3  Well, the sun is shinin? a new day is here  \r...
# 4  Nature has some new plague  \r\nTo run in our ...
# 5  There were the trees, see the grass, a thing g...
# 6  Excellent birds  \r\n  \r\nFlying birds  \r\nE...
# 7  [Chorus]  \r\nCrocodile on my feet  \r\nFox fu...
# 8  YAH YAH HABIBI WEN ISALAM?!  \r\nGULI KALAM......
# 9  After all this time, I still miss you everyday...

# %%
df['text'][0]
# Out:
# "Five AM in the mornin', whiskey still runnin' through my head  \r\nI could get out of bed and maybe I'll just have another cigarette  \r\nAs long as I can remember seems all I've ever done is work  \r\nThe boss is a jerk and I ain't payin' the rent  \r\nSpent my whole life shovelin' dirt  \r\n  \r\n[Chorus]  \r\nI'm gonna get outta hell in my dodge  \r\nCan't take this anymore  \r\nGonna go downtown pick up my girl  \r\nThere ain't nothin' worth waitin' for  \r\nTake the road less traveled  \r\nSpend my life behind the wheel  \r\nGonna get outta hell in my dodge  \r\nFreedom made out of steel  \r\n  \r\nThere's a knock on the door from the sheriff  \r\nAskin' me where I was last night  \r\nSeems somebody lookin' a lot like me  \r\nHad takin' up with his wife  \r\nHe said son if I ever catch him  \r\nThere's gonna be some hell to pay  \r\nHe'll be gone for good if I see him again  \r\n'cause I just might blow him away  \r\n  \r\n[Chorus]  \r\n  \r\nWhat's a poor man supposed to do  \r\nStuck in the middle and trapped by the blues  \r\nBaby, I'm sick of these blues  \r\n  \r\nI'm gonna get outta hell in my dodge  \r\nCan't take this anymore  \r\nGonna go downtown pick up my girl  \r\nThere ain't nothin' worth waitin' for  \r\nWell I don't care if I'm wrong or right  \r\nGotta split this town tonight  \r\nGonna get outta hell in my dodge  \r\nLive my life behind the wheel  \r\nI'm gonna get outta hell in my dodge  \r\nMy freedom made out of steel\r\n\r\n"

# %%
# df = df.sample(5000)

# %%
df.shape
# Out:
# (5000, 3)

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
from nltk.corpus import brown
brown.words()

# %%
nltk.set_proxy('http://proxy.example.com:3128', ('USERNAME', 'PASSWORD'))
nltk.download()

# %%
import nltk
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

def tokenization(txt):
    tokens = nltk.word_tokenize(txt)
    stemming = [stemmer.stem(w) for w in tokens]
    return " ".join(stemming)

# %%
df['text'] = df['text'].apply(lambda x: tokenization(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidvector = TfidfVectorizer(analyzer='word',stop_words='english')
matrix = tfidvector.fit_transform(df['text'])
similarity = cosine_similarity(matrix)

# %%
similarity[0]

# %%
df[df['song'] == 'Crying Over You']

# %%
def recommendation(song_df):
    idx = df[df['song'] == song_df].index[0]
    distances = sorted(list(enumerate(similarity[idx])),reverse=True,key=lambda x:x[1])
    
    songs = []
    for m_id in distances[1:21]:
        songs.append(df.iloc[m_id[0]].song)
        
    return songs

# %%
recommendation('Crying Over You')

# %%
import pickle
pickle.dump(similarity,open('similarity.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))
